# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 129.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="dcZKRj2xqwPU94CoAUcS")
project = rf.workspace("sebas-xxi8x").project("dataset-millonarios")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to dataset-millonarios-3 in yolov8:: 100%|██████████| 834/834 [00:00<00:00, 5657.25it/s]

# %%
import os

# Check dataset structure
dataset_path = "/content/dataset-millonarios-3"  # Replace if the dataset path differs
print(os.listdir(dataset_path))

# Inspect the `data.yaml`
with open(os.path.join(dataset_path, "data.yaml"), "r") as file:
    print(file.read())
# Out:
# ['README.dataset.txt', 'train', 'data.yaml', 'README.roboflow.txt', 'valid', 'test']
# names:
# - arbitro
# - arco
# - balon
# - jugador
# - soccer
# nc: 5
# roboflow:
#   license: CC BY 4.0
#   project: dataset-millonarios
#   url: https://universe.roboflow.com/sebas-xxi8x/dataset-millonarios/dataset/3
#   version: 3
#   workspace: sebas-xxi8x
# test: ../test/images
# train: ../train/images
# val: ../valid/images

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 125.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Initialize the model
model = YOLO('yolov8s.pt')  # You can use yolov8n, yolov8s, yolov8m, etc., based on your system's capability

# Train the model
model.train(data=os.path.join(dataset_path, "data.yaml"), epochs=30, imgsz=640)

# Results are saved in `runs/detect/train`
# Out:
# Ultralytics 8.3.119 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/Basketball-Shooting-Robot-1/valid/labels.cache... 1145 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1145/1145 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 72/72 [00:19<00:00,  3.78it/s]
#                    all       1145       1183      0.979      0.966      0.986      0.903
# Speed: 0.3ms preprocess, 9.5ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/train2
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7a07b5e0ab00>
# ...

# %%
from ultralytics import YOLO

# Cargar el modelo YOLO
model = YOLO("/content/runs/detect/train/weights/best.pt")  # Cambia "yolov8n.pt" por tu modelo personalizado.

# Ruta de la imagen a procesar
input_path = "/content/videobasket.mp4"  # Cambia esto por el path a tu archivo.

# Realizar detecciones con YOLO y guardar la imagen procesada
results = model(input_path, conf =0.4,save=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (frame 3364/9438) /content/videobasket.mp4: 480x640 (no detections), 9.7ms
# video 1/1 (frame 3365/9438) /content/videobasket.mp4: 480x640 (no detections), 7.9ms
# video 1/1 (frame 3366/9438) /content/videobasket.mp4: 480x640 (no detections), 8.1ms
# video 1/1 (frame 3367/9438) /content/videobasket.mp4: 480x640 (no detections), 7.7ms
# video 1/1 (frame 3368/9438) /content/videobasket.mp4: 480x640 (no detections), 7.6ms
# video 1/1 (frame 3369/9438) /content/videobasket.mp4: 480x640 (no detections), 7.8ms
# video 1/1 (frame 3370/9438) /content/videobasket.mp4: 480x640 (no detections), 7.7ms
# video 1/1 (frame 3371/9438) /content/videobasket.mp4: 480x640 (no detections), 7.7ms
# video 1/1 (frame 3372/9438) /content/videobasket.mp4: 480x640 (no detections), 7.7ms
# video 1/1 (frame 3373/9438) /content/videobasket.mp4: 480x640 (no detections), 8.7ms
# ...
